# %%
# Out:
# 202

# %%
import polars as pl
#df = pl.read_parquet("../data/nlp_enriched/nlp_enriched_NAMO_preprocessed_test_final.parquet")
df = pl.read_csv("../data/NAMO_2025_09.csv")

# %%
df
# Out:
# shape: (953_846, 11)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ url        ┆ title     ┆ descripti ┆ content   ┆ … ┆ domain    ┆ country ┆ content_l ┆ scraped_a │
# │ ---        ┆ ---       ┆ on        ┆ ---       ┆   ┆ ---       ┆ ---     ┆ ength     ┆ t         │
# │ str        ┆ str       ┆ ---       ┆ str       ┆   ┆ str       ┆ str     ┆ ---       ┆ ---       │
# │            ┆           ┆ str       ┆           ┆   ┆           ┆         ┆ i64       ┆ str       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ https://ww ┆ Elon Musk ┆ null      ┆ ØKONOMISK ┆ … ┆ www.frihe ┆ norway  ┆ null      ┆ null      │
# │ w.frihetsk ┆ saksøkt   ┆           ┆ KRIMINALI ┆   ┆ tskamp.no ┆         ┆           ┆           │
# │ amp.no/elo ┆ for       ┆           ┆ TET       ┆   ┆           ┆         ┆           ┆           │
# ...

# %%
df.write_csv("../data/nlp_enriched/nlp_enriched_NAMO_preprocessed_test_final.csv")
